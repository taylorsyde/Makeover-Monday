# %%
import pandas as pd

# %%
df = pd.read_excel('Resources/Full_New_Years_Resolutions_Gender_Age_Breakdown.xlsx')

# %%
df.loc[df.Reso]
# Out:
#                                   Resolution  Male  Female  18-24  25-49  \
# 0   Doing more exercise or improving fitness    49      61     53     54
# 1                          Saving more money    43      52     61     56
# 2                              Losing weight    43      47     40     43
# 3                          Improving my diet    41      43     45     44
# 4         Spending less time on social media    21      21     31     21
# 5                 Pursuing a career ambition    26      16     40     19
# 6          Spending more time with my family    20      21     25     22
# 7                      Taking up a new hobby    21      18     32     20
# 8   Decorating or renovating part of my home     9      18     12     14
# 9    Volunteering or doing more charity work    18      11     18     12
# 10                  Cutting down on drinking    13      11      6     14
# 11                         Giving up smoking     4       8      2      8
# ...
